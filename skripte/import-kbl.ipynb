# %%
import pandas as pd

# %%
df = pd.read_csv('../raw/kunstblattsammlung.csv',skipinitialspace=True)
# df['period'] = df[['Year', 'quarter', ...]].agg('-'.join, axis=1)
df.head()
# Out:
#         signatur          urheber urheber_idn               titel zusatztitel  \
# 0  Kbl 1960 C 83   Ackermann, Max   118500473          Jubilieren         NaN
# 1  Kbl 1967 C 41   Ackermann, Max   118500473  Triumph der Freude         NaN
# 2  Kbl 1960 C 80   Ackermann, Max   118500473     Über den Türmen         NaN
# 3  Kbl 1957 C 86   Ackermann, Max   118500473      Weißes Zeichen         NaN
# 4  Kbl 1962 C 13  D'Altri, Arnold   119230887               Idole         NaN
#
#                  technik                ort           verlag  jahr  blattmass  \
# 0   Mehrfarb. Lichtdruck     Eßlingen a. N.   Fingerle & Co.  1957  940 x 685
# 1   Mehrfarb. Lichtdruck          Esslingen   Fingerle & Co.  1962  695 x 490
# 2   Mehrfarb. Lichtdruck     Eßlingen a. N.   Fingerle & Co.  1958  620 x 485
# 3   Mehrfarb. Lichtdruck            Dresden   Verl. d. Kunst  1957  620 x 500
# 4  Mehrfarb. Offsetdruck  Viernheim, Zürich  Viernheim-Verl.  1962  480 x 600
#
# ...

# %%
pd.Series(df.technik.unique()).sort_values().to_csv('../dat/techniken.csv', index=False)
